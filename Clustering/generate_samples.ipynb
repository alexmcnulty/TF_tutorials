# %%
# %matplotlib inline  
# %run 'functions.ipynb'

import tensorflow as tf
import numpy as np

# %%
n_clusters = 3
n_points = 500

centroids, samples = create_samples(n_clusters, n_points)

model = tf.initialize_all_variables()
with tf.Session() as session:
    sample_values = session.run(samples)
    centroid_values = session.run(centroids)
    
plot_clusters(sample_values, centroid_values, n_points)
